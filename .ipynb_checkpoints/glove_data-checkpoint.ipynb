# %%
import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
#from model_arch import *
import csv, sys, pdb
from sklearn.ensemble import AdaBoostClassifier

# %%
file_rigid_accel2 = "/home/togzhan/sample/data/rigid_accel2.csv"
file_rigid_accel = "/home/togzhan/sample/data/rigid_accel.csv"
file_rigid_pressure = "/home/togzhan/sample/data/rigid_pressure.csv"
file_rigid_imu = "/home/togzhan/sample/data/rigid_imu.csv"


file_soft_accel2 = "/home/togzhan/sample/data/soft_accel2.csv"
file_soft_accel = "/home/togzhan/sample/data/soft_accel.csv"
file_soft_pressure = "/home/togzhan/sample/data/soft_pressure.csv"
file_soft_imu = "/home/togzhan/sample/data/soft_imu.csv"

df_accel2_rigid = pd.read_csv(file_rigid_accel2, sep = ',', header = None)
df_accel_rigid = pd.read_csv(file_rigid_accel, sep = ',', header = None)
df_pressure_rigid = pd.read_csv(file_rigid_pressure, sep = ',', header = None)
df_imu_rigid = pd.read_csv(file_rigid_imu, sep = ',', header = None)

df_accel2_soft = pd.read_csv(file_soft_accel2, sep = ',', header = None)
df_accel_soft = pd.read_csv(file_soft_accel, sep = ',', header = None)
df_pressure_soft = pd.read_csv(file_soft_pressure, sep = ',', header = None)
df_imu_soft = pd.read_csv(file_soft_imu, sep = ',', header = None)

# %%
norma
# Out:
# (37200, 27)

# %%
def combine_the_data(df_accel2, df_pressure, df_imu, inp):
    df_pressure_n = normalize(df_pressure)
    dP = pd.DataFrame()
    dA = pd.DataFrame()
    dI = pd.DataFrame()
    D = pd.DataFrame()
    data = pd.DataFrame()
    df_accelT = df_accel2.transpose()
    df_pressure_nT = df_pressure_n.transpose()
    df_imuT = df_imu.transpose()
    for i in range(50):
        P = pd.DataFrame()
        A = pd.DataFrame()
        I = pd.DataFrame()
        for j in range(27):
            p = []
            p = df_pressure_nT.values[j, i*744:(i+1)*744]
            P = pd.concat([P, pd.DataFrame(p)], axis = 0)
        for j in range(200):
            a = []
            a = df_accelT.values[j, i*744:(i+1)*744]
            A = pd.concat([A, pd.DataFrame(a)], axis = 0)
        for j in range(18):
            ii = []
            ii = df_imuT.values[j, i*744:(i+1)*744]
            I = pd.concat([I, pd.DataFrame(ii)], axis = 0)
        
        D = pd.concat([P, A, I], axis = 0)
        
        data = pd.concat([data, D], axis = 1)
#         dP = pd.concat([dP, P], axis = 1)
#         dA = pd.concat([dA, A], axis = 1)
#         dI = pd.concat([dI, I], axis = 1)
    return data
# Out:
# (182280, 50)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(50):
    df_accel_rigid = df_accel_rigid.transpose()
    df_data_s = df_data_soft.transpose()
    df_rigid = pd.DataFrame()
    df_soft = pd.DataFrame()
    data = pd.DataFrame()
    for i in range(50):
        ddd = pd.DataFrame()
        dd = pd.DataFrame()
        for j in range(244):
            a = []
            a = df_data_r.values[j, i*744:(i+1)*744]
            b = []
            b = df_data_s.values[j, i*744:(i+1)*744]
            ddd = pd.concat([ddd, pd.DataFrame(a)], axis = 0)
            dd = pd.concat([dd, pd.DataFrame(b)], axis = 0)
        df_rigid = pd.concat([df_rigid, ddd], axis = 1)
        df_soft = pd.concat([df_soft, ddd], axis = 1)
        
    data = pd.concat([df_soft, df_rigid], axis = 1, ignore_index=True)
    return data.transpose()

# data in format 244*744 by 100 - # of traials 
df_data_all = combine(df_data_rigid, df_data_soft)
df_data_all.columns = range(df_data_all.shape[1])

# %%
#######################################################
def normalize(data):
    m = data.max()
    data = pd.DataFrame(data)
#     df_max = [420, 420, 420, 418, 418, 450, 432, 432, 432, 390, 472, 480, 480, 480, 435, 433, 501, 405, 400, 400, 400 ,400, 370, 455 ,444, 310, 445]
    df_max = [450]
    df_max = pd.DataFrame(df_max)
    df_min = 0;
    p = pd.DataFrame()
    k = []
    for i in range(27):
        k = np.divide(data.values[:,i].astype('float'), df_max.values[0].astype('float'))
        k = pd.DataFrame(k)    
        p = pd.concat([p, k], axis = 1)
        
    data = p
    data = pd.DataFrame(p)
    return data
#######################################################
df_pressure_rigid_n = pd.DataFrame()
df_pressure_soft_n = pd.DataFrame()
df_pressure_rigid_n = normalize(df_pressure_rigid)
df_pressure_soft_n = normalize(df_pressure_soft)

# %%
df_pressure_rigid_n = df_pressure_rigid_n.transpose()
df_pressure_rigid_n.shape
# Out:
# (27, 37200)

# %%
file_data_rigid = "/home/togzhan/sample/data/data/data_rigid.csv"
data_rigid = pd.read_csv(file_data_rigid, sep = ',', header = None, index_col=None)

file_data_soft = "/home/togzhan/sample/data/data/data_soft.csv"
data_soft = pd.read_csv(file_data_soft, sep = ',', header = None, index_col=None)

# %%
df_data_rigid = pd.DataFrame()
df_data_soft = pd.DataFrame()
df_data = pd.DataFrame()

df_data_rigid = pd.concat([df_pressure_rigid_n, df_accel2_rigid, df_imu_rigid], axis = 1, sort = False)
df_data_soft = pd.concat([df_pressure_soft_n, df_accel2_soft, df_imu_soft], axis = 1, sort = False)

    # data in format 244 - #of feautures and 100*744
df_data = pd.concat([df_pressure_soft_n, df_accel2_soft, df_imu_soft], axis = 1, sort = False, ignore_index=True)

# %%
# combine data by the feautures  244 feautures
def combine_a_i_p(a, i, p): 
    df_data = pd.DataFrame()
    df_data = pd.concat([p, a, i], axis = 1, sort = False)
    # data in format 244 - #of feautures and 100*744
    return df_data

# %%
def combine(df_data_rigid, df_data_soft):
    df_data_r = df_data_rigid.transpose()
    df_data_s = df_data_soft.transpose()
    df_rigid = pd.DataFrame()
    df_soft = pd.DataFrame()
    data = pd.DataFrame()
    for i in range(50):
        ddd = pd.DataFrame()
        dd = pd.DataFrame()
        for j in range(244):
            a = []
            a = df_data_r.values[j, i*744:(i+1)*744]
            b = []
            b = df_data_s.values[j, i*744:(i+1)*744]
            ddd = pd.concat([ddd, pd.DataFrame(a)], axis = 0)
            dd = pd.concat([dd, pd.DataFrame(b)], axis = 0)
        df_rigid = pd.concat([df_rigid, ddd], axis = 1)
        df_soft = pd.concat([df_soft, ddd], axis = 1)
        
    data = pd.concat([df_soft, df_rigid], axis = 1, ignore_index=True)
    return data.transpose()

# data in format 244*744 by 100 - # of traials 
df_data_all = combine(df_data_rigid, df_data_soft)
df_data_all.columns = range(df_data_all.shape[1])

######################################################
# df_data_r = combine_data(pressure_n, accelerometer, imu)

# %%
df_bilabel = []
for i in range(100):
    if(i<50):
        df_bilabel.append(0)
    else:
        df_bilabel.append(1)
df_bilabel = pd.DataFrame(df_bilabel, index=None)

k = 0
labels = []
for i in range(100):
    if(np.mod(i,5) == 0):
        k = k +1
    labels.append(k)        
df_label = pd.DataFrame(labels, index=None)

# labels - 1st number 0 or 1 0 - rigid 1 - soft, second number defines the object
df_newlabel = df_bilabel.astype(str) + "_" + df_label.astype(str)

# %%
df_data_l = pd.DataFrame()
# df_data_l = pd.concat([df_data_all, labels], axis = 1, sort = False)
df_data_l = pd.concat([df_data_all,df_bilabel], axis=1, sort=False)
df_train, df_eval = train_test_split(df_data_all, test_size=1.0/3, random_state=777, stratify=df_newlabel.values)

# %%
#save the data 
df_data.to_csv(path_or_buf="/home/togzhan/sample/data/data/df_data.csv", index=False) 

df_data_all.to_csv(path_or_buf="/home/togzhan/sample/data/data/df_data_all.csv", index=False) 

df_train.to_csv(path_or_buf="/home/togzhan/sample/data/data/df_train2.csv", index=False) 

df_eval.to_csv(path_or_buf="/home/togzhan/sample/data/data/df_eval2.csv", index=False)

# %%
df_train2 = "/home/togzhan/sample/data/data/df_train2.csv"
df_eval2 = "/home/togzhan/sample/data/data/df_eval2.csv"

df_train = pd.read_csv(df_train2, sep = ',', header = None)
df_eval = pd.read_csv(df_eval2, sep = ',', header = None)

# %%
train_y = torch.FloatTensor(df_train.values[:,1].astype('float64'))

train_x	= torch.FloatTensor(df_train.values[:,:-3].astype('float64'))

# %%
print pd.DataFrame(train_x)
# Out:
#             0               1               2               3       \
# 0       tensor(0.)      tensor(1.)      tensor(2.)      tensor(3.)
# 1   tensor(0.0933)  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)
# 2   tensor(0.1200)  tensor(0.1222)  tensor(0.1222)  tensor(0.1222)
# 3   tensor(0.0844)  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)
# 4   tensor(0.0867)  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)
# 5   tensor(0.0044)  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)
# 6   tensor(0.0111)  tensor(0.0133)  tensor(0.0133)  tensor(0.0133)
# 7   tensor(0.0022)  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)
# 8   tensor(0.1000)  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)
# 9   tensor(0.0044)  tensor(0.0044)  tensor(0.0044)      tensor(0.)
# 10  tensor(0.0356)  tensor(0.0333)  tensor(0.0333)  tensor(0.0333)
# 11  tensor(0.0867)  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)
# 12  tensor(0.0978)  tensor(0.1022)  tensor(0.1022)  tensor(0.1022)
# 13  tensor(0.0956)  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)
# 14  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)
# 15  tensor(0.0044)  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)
# 16  tensor(0.0133)  tensor(0.0178)  tensor(0.0178)  tensor(0.0178)
# 17  tensor(0.0067)  tensor(0.0044)  tensor(0.0044)  tensor(0.0067)
# 18  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 19  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)
# 20  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 21      tensor(0.)  tensor(0.0022)  tensor(0.0022)      tensor(0.)
# 22  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)
# 23  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 24  tensor(0.0978)  tensor(0.1022)  tensor(0.1022)  tensor(0.1022)
# 25  tensor(0.0044)  tensor(0.0044)  tensor(0.0022)  tensor(0.0022)
# 26  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 27  tensor(0.0956)  tensor(0.0956)  tensor(0.0956)  tensor(0.0956)
# 28  tensor(0.0956)  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)
# 29      tensor(0.)      tensor(0.)      tensor(0.)      tensor(0.)
# ..             ...             ...             ...             ...
# 37  tensor(0.0356)  tensor(0.0333)  tensor(0.0333)  tensor(0.0333)
# 38      tensor(0.)      tensor(0.)      tensor(0.)      tensor(0.)
# 39  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 40  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)
# 41  tensor(0.0911)  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)
# 42  tensor(0.0022)      tensor(0.)      tensor(0.)      tensor(0.)
# 43  tensor(0.0844)  tensor(0.0844)  tensor(0.0844)  tensor(0.0844)
# 44  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)
# 45  tensor(0.8778)  tensor(0.8778)  tensor(0.8778)  tensor(0.8778)
# 46      tensor(0.)  tensor(0.0022)  tensor(0.0022)      tensor(0.)
# 47  tensor(0.0156)  tensor(0.0156)  tensor(0.0156)  tensor(0.0156)
# 48  tensor(0.0022)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 49  tensor(0.1244)  tensor(0.1200)  tensor(0.1200)  tensor(0.1200)
# 50  tensor(0.0956)  tensor(0.0956)  tensor(0.0956)  tensor(0.0956)
# 51  tensor(0.0311)  tensor(0.0311)  tensor(0.0311)  tensor(0.0311)
# 52  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 53  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 54  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 55  tensor(0.1000)  tensor(0.1044)  tensor(0.1044)  tensor(0.1044)
# 56  tensor(0.1356)  tensor(0.1356)  tensor(0.1356)  tensor(0.1356)
# 57  tensor(0.1000)  tensor(0.0978)  tensor(0.0978)  tensor(0.0978)
# 58  tensor(0.0133)  tensor(0.0178)  tensor(0.0178)  tensor(0.0178)
# 59  tensor(0.0067)  tensor(0.0044)  tensor(0.0044)  tensor(0.0067)
# 60  tensor(0.1711)  tensor(0.1733)  tensor(0.1733)  tensor(0.1733)
# 61  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)      tensor(0.)
# 62  tensor(0.0133)  tensor(0.0444)  tensor(0.0444)  tensor(0.0444)
# 63  tensor(0.1000)  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)
# 64  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)  tensor(0.0889)
# 65  tensor(0.0133)  tensor(0.0444)  tensor(0.0444)  tensor(0.0444)
# 66  tensor(0.1711)  tensor(0.1733)  tensor(0.1733)  tensor(0.1733)
#
#             4               5               6               7       \
# 0       tensor(4.)      tensor(5.)      tensor(6.)      tensor(7.)
# 1   tensor(0.0933)  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)
# 2   tensor(0.1222)  tensor(0.1222)  tensor(0.1222)  tensor(0.1222)
# 3   tensor(0.0844)  tensor(0.0844)  tensor(0.0844)  tensor(0.0844)
# 4   tensor(0.0867)  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)
# 5   tensor(0.0022)  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)
# 6   tensor(0.0156)  tensor(0.0156)  tensor(0.0156)  tensor(0.0222)
# 7   tensor(0.0022)  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)
# 8   tensor(0.1000)  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)
# 9       tensor(0.)      tensor(0.)      tensor(0.)  tensor(0.0044)
# 10  tensor(0.0333)  tensor(0.0333)  tensor(0.0333)  tensor(0.0289)
# 11  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)
# 12  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)
# 13  tensor(0.0800)  tensor(0.0800)  tensor(0.0800)  tensor(0.0267)
# 14  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)  tensor(0.0222)
# 15  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)  tensor(0.0022)
# 16  tensor(0.0178)  tensor(0.0178)  tensor(0.0178)  tensor(0.0244)
# 17  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)  tensor(0.0044)
# 18  tensor(0.0044)  tensor(0.0044)  tensor(0.0067)  tensor(0.0067)
# 19  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)
# 20  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 21      tensor(0.)      tensor(0.)      tensor(0.)      tensor(0.)
# 22  tensor(0.1000)  tensor(0.0978)  tensor(0.0978)  tensor(0.0978)
# 23  tensor(0.0044)  tensor(0.0044)  tensor(0.0067)  tensor(0.0067)
# 24  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)  tensor(0.1000)
# 25  tensor(0.0022)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 26  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 27  tensor(0.0956)  tensor(0.0956)  tensor(0.0956)  tensor(0.0978)
# 28  tensor(0.0800)  tensor(0.0800)  tensor(0.0800)  tensor(0.0267)
# 29      tensor(0.)      tensor(0.)      tensor(0.)      tensor(0.)
# ..             ...             ...             ...             ...
# 37  tensor(0.0333)  tensor(0.0333)  tensor(0.0333)  tensor(0.0289)
# 38      tensor(0.)      tensor(0.)      tensor(0.)      tensor(0.)
# 39  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0022)
# 40  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)
# 41  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)  tensor(0.0911)
# 42      tensor(0.)      tensor(0.)      tensor(0.)  tensor(0.0022)
# 43  tensor(0.0844)  tensor(0.0844)  tensor(0.0844)  tensor(0.0844)
# 44  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)  tensor(0.0222)
# 45  tensor(0.8778)  tensor(0.8778)  tensor(0.8778)  tensor(0.8778)
# 46      tensor(0.)      tensor(0.)      tensor(0.)      tensor(0.)
# 47  tensor(0.0156)  tensor(0.0156)  tensor(0.0156)  tensor(0.0156)
# 48  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0022)
# 49  tensor(0.1178)  tensor(0.1178)  tensor(0.1178)  tensor(0.1156)
# 50  tensor(0.0956)  tensor(0.0956)  tensor(0.0956)  tensor(0.0978)
# 51  tensor(0.0133)  tensor(0.0089)  tensor(0.0089)  tensor(0.0089)
# 52  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 53  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 54  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)  tensor(0.0044)
# 55  tensor(0.1022)  tensor(0.1022)  tensor(0.1022)  tensor(0.1022)
# 56  tensor(0.1311)  tensor(0.1311)  tensor(0.1311)  tensor(0.1311)
# 57  tensor(0.0978)  tensor(0.0978)  tensor(0.0978)  tensor(0.0956)
# 58  tensor(0.0178)  tensor(0.0178)  tensor(0.0178)  tensor(0.0244)
# 59  tensor(0.0067)  tensor(0.0067)  tensor(0.0067)  tensor(0.0044)
# 60  tensor(0.1733)  tensor(0.1733)  tensor(0.1733)  tensor(0.1733)
# 61      tensor(0.)      tensor(0.)      tensor(0.)  tensor(0.0044)
# 62  tensor(0.0444)  tensor(0.0444)  tensor(0.0444)  tensor(0.0822)
# 63  tensor(0.0933)  tensor(0.0933)  tensor(0.0933)  tensor(0.0889)
# 64  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)  tensor(0.0867)
# 65  tensor(0.0444)  tensor(0.0444)  tensor(0.0444)  tensor(0.0822)
# 66  tensor(0.1733)  tensor(0.1733)  tensor(0.1733)  tensor(0.1733)
#
#             8               9       ...             181523             181524  \
# 0       tensor(8.)      tensor(9.)  ...    tensor(181523.)    tensor(181524.)
# 1   tensor(0.0933)  tensor(0.0933)  ...   tensor(-17.7418)   tensor(-17.7418)
# 2   tensor(0.1222)  tensor(0.1222)  ...    tensor(63.2682)    tensor(63.2682)
# 3   tensor(0.0844)  tensor(0.0844)  ...    tensor(82.8870)    tensor(82.8870)
# 4   tensor(0.0867)  tensor(0.0867)  ...    tensor(47.3318)    tensor(47.3318)
# 5   tensor(0.0022)  tensor(0.0022)  ...    tensor(88.4885)    tensor(88.4885)
# 6   tensor(0.0222)  tensor(0.0244)  ...   tensor(-67.5295)   tensor(-67.5295)
# 7   tensor(0.0022)  tensor(0.0022)  ...   tensor(-78.5238)   tensor(-78.5238)
# 8   tensor(0.1000)  tensor(0.1000)  ...    tensor(94.2335)    tensor(94.2335)
# 9   tensor(0.0044)  tensor(0.0044)  ...   tensor(-48.5875)   tensor(-48.5875)
# 10  tensor(0.0289)  tensor(0.0289)  ...  tensor(-119.2548)  tensor(-119.2548)
# 11  tensor(0.0867)  tensor(0.0867)  ...    tensor(28.8625)    tensor(28.8625)
# 12  tensor(0.1022)  tensor(0.1022)  ...    tensor(94.2335)    tensor(94.2335)
# 13  tensor(0.0267)  tensor(0.0267)  ...    tensor(44.3323)    tensor(44.3323)
# 14  tensor(0.0222)  tensor(0.0400)  ...    tensor(24.2229)    tensor(24.2229)
# 15  tensor(0.0022)  tensor(0.0022)  ...    tensor(88.4885)    tensor(88.4885)
# 16  tensor(0.0244)  tensor(0.0244)  ...   tensor(-82.1941)   tensor(-82.1941)
# 17  tensor(0.0044)  tensor(0.0044)  ...   tensor(103.0653)   tensor(103.0653)
# 18  tensor(0.0067)  tensor(0.0067)  ...    tensor(74.3538)    tensor(74.3538)
# 19  tensor(0.0867)  tensor(0.0867)  ...   tensor(166.9507)   tensor(166.9507)
# 20  tensor(0.0044)  tensor(0.0044)  ...   tensor(-54.3524)   tensor(-54.3524)
# 21      tensor(0.)      tensor(0.)  ...   tensor(157.6986)   tensor(157.6986)
# 22  tensor(0.1000)  tensor(0.1000)  ...    tensor(94.2335)    tensor(94.2335)
# 23  tensor(0.0067)  tensor(0.0067)  ...    tensor(74.3538)    tensor(74.3538)
# 24  tensor(0.1022)  tensor(0.1022)  ...    tensor(94.2335)    tensor(94.2335)
# 25  tensor(0.0044)  tensor(0.0044)  ...  tensor(-106.3798)  tensor(-106.3798)
# 26  tensor(0.0044)  tensor(0.0044)  ...  tensor(-103.3455)  tensor(-103.3455)
# 27  tensor(0.0978)  tensor(0.0978)  ...  tensor(-128.9270)  tensor(-128.9270)
# 28  tensor(0.0267)  tensor(0.0267)  ...    tensor(44.3323)    tensor(44.3323)
# 29      tensor(0.)      tensor(0.)  ...   tensor(128.1160)   tensor(128.1160)
# ..             ...             ...  ...                ...                ...
# 37  tensor(0.0289)  tensor(0.0289)  ...  tensor(-119.2548)  tensor(-119.2548)
# 38      tensor(0.)      tensor(0.)  ...   tensor(128.1160)   tensor(128.1160)
# 39  tensor(0.0022)  tensor(0.0022)  ...   tensor(167.3797)   tensor(167.3797)
# 40  tensor(0.0933)  tensor(0.0933)  ...   tensor(-17.7418)   tensor(-17.7418)
# 41  tensor(0.0911)  tensor(0.0911)  ...   tensor(-68.2657)   tensor(-68.2657)
# 42  tensor(0.0022)  tensor(0.0022)  ...   tensor(158.1229)   tensor(158.1229)
# 43  tensor(0.0844)  tensor(0.0844)  ...    tensor(-3.7204)    tensor(-3.7204)
# 44  tensor(0.0222)  tensor(0.0400)  ...    tensor(24.2229)    tensor(24.2229)
# 45  tensor(0.8778)  tensor(0.8778)  ...   tensor(128.4599)   tensor(128.4599)
# 46      tensor(0.)      tensor(0.)  ...   tensor(157.6986)   tensor(157.6986)
# 47  tensor(0.0156)  tensor(0.0156)  ...   tensor(-26.6565)   tensor(-26.6565)
# 48  tensor(0.0022)  tensor(0.0022)  ...    tensor(94.2335)    tensor(94.2335)
# 49  tensor(0.1156)  tensor(0.1156)  ...    tensor(70.7031)    tensor(70.7031)
# 50  tensor(0.0978)  tensor(0.0978)  ...  tensor(-128.9270)  tensor(-128.9270)
# 51  tensor(0.0089)  tensor(0.0089)  ...     tensor(3.2087)     tensor(3.2087)
# 52  tensor(0.0044)  tensor(0.0044)  ...    tensor(94.2335)    tensor(94.2335)
# 53  tensor(0.0044)  tensor(0.0044)  ...    tensor(94.2335)    tensor(94.2335)
# 54  tensor(0.0044)  tensor(0.0044)  ...  tensor(-155.5714)  tensor(-155.5714)
# 55  tensor(0.1022)  tensor(0.1022)  ...    tensor(94.2335)    tensor(94.2335)
# 56  tensor(0.1311)  tensor(0.1311)  ...    tensor(82.2206)    tensor(82.2206)
# 57  tensor(0.0956)  tensor(0.0956)  ...    tensor(94.2335)    tensor(94.2335)
# 58  tensor(0.0244)  tensor(0.0244)  ...   tensor(-82.1941)   tensor(-82.1941)
# 59  tensor(0.0044)  tensor(0.0044)  ...   tensor(103.0653)   tensor(103.0653)
# 60  tensor(0.1733)  tensor(0.1733)  ...    tensor(60.8131)    tensor(60.8131)
# 61  tensor(0.0044)  tensor(0.0044)  ...   tensor(-48.5875)   tensor(-48.5875)
# 62  tensor(0.0822)  tensor(0.0822)  ...    tensor(69.4775)    tensor(69.4775)
# 63  tensor(0.0889)  tensor(0.0889)  ...    tensor(91.5914)    tensor(91.5914)
# 64  tensor(0.0867)  tensor(0.0867)  ...   tensor(166.9507)   tensor(166.9507)
# 65  tensor(0.0822)  tensor(0.0822)  ...    tensor(69.4775)    tensor(69.4775)
# 66  tensor(0.1733)  tensor(0.1733)  ...    tensor(60.8131)    tensor(60.8131)
#
#                181525             181526             181527  \
# 0     tensor(181525.)    tensor(181526.)    tensor(181527.)
# 1    tensor(-17.7418)   tensor(-17.7418)   tensor(-17.7418)
# 2     tensor(63.2682)    tensor(63.2682)    tensor(63.2682)
# 3     tensor(82.8870)    tensor(82.8870)    tensor(82.8870)
# 4    tensor(167.7155)   tensor(167.7155)   tensor(167.7155)
# 5     tensor(88.4885)    tensor(88.4885)    tensor(88.4885)
# 6    tensor(-67.5295)   tensor(-67.5295)   tensor(-67.5295)
# 7    tensor(-78.5238)   tensor(-78.5238)   tensor(-78.5238)
# 8     tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 9    tensor(149.1525)   tensor(149.1525)   tensor(149.1525)
# 10  tensor(-119.2548)  tensor(-119.2548)  tensor(-119.2548)
# 11    tensor(28.8625)    tensor(28.8625)    tensor(28.8625)
# 12    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 13    tensor(44.3323)    tensor(44.3323)    tensor(44.3323)
# 14    tensor(24.2229)    tensor(24.2229)    tensor(24.2229)
# 15    tensor(88.4885)    tensor(88.4885)    tensor(88.4885)
# 16  tensor(-177.9646)  tensor(-177.9646)  tensor(-177.9646)
# 17   tensor(103.0653)   tensor(103.0653)   tensor(103.0653)
# 18    tensor(74.3538)    tensor(74.3538)    tensor(74.3538)
# 19   tensor(166.9507)   tensor(166.9507)   tensor(166.9507)
# 20   tensor(-54.3524)   tensor(-54.3524)   tensor(-54.3524)
# 21   tensor(157.6986)   tensor(157.6986)   tensor(157.6986)
# 22    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 23    tensor(74.3538)    tensor(74.3538)    tensor(74.3538)
# 24    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 25  tensor(-106.3798)  tensor(-106.3798)  tensor(-153.6011)
# 26  tensor(-103.3455)  tensor(-103.3455)  tensor(-103.3455)
# 27  tensor(-128.9270)  tensor(-128.9270)  tensor(-128.9270)
# 28    tensor(44.3323)    tensor(44.3323)    tensor(44.3323)
# 29   tensor(128.1160)   tensor(128.1160)   tensor(128.1160)
# ..                ...                ...                ...
# 37  tensor(-119.2548)  tensor(-119.2548)  tensor(-119.2548)
# 38   tensor(128.1160)   tensor(128.1160)   tensor(128.1160)
# 39   tensor(-67.7747)   tensor(-67.7747)   tensor(-67.7747)
# 40   tensor(-17.7418)   tensor(-17.7418)   tensor(-17.7418)
# 41   tensor(-68.2657)   tensor(-68.2657)   tensor(-68.2657)
# 42   tensor(158.1229)   tensor(158.1229)   tensor(158.1229)
# 43    tensor(-3.7204)    tensor(-3.7204)    tensor(-3.7204)
# 44    tensor(24.2229)    tensor(24.2229)    tensor(24.2229)
# 45   tensor(128.4599)   tensor(128.4599)   tensor(128.4599)
# 46   tensor(157.6986)   tensor(157.6986)   tensor(157.6986)
# 47   tensor(-26.6565)   tensor(-26.6565)   tensor(-26.6565)
# 48    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 49    tensor(70.7031)    tensor(70.7031)    tensor(70.7031)
# 50  tensor(-128.9270)  tensor(-128.9270)  tensor(-128.9270)
# 51     tensor(3.2087)     tensor(3.2087)     tensor(3.2087)
# 52    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 53    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 54  tensor(-155.5714)  tensor(-155.5714)  tensor(-155.5714)
# 55    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 56    tensor(82.2206)    tensor(82.2206)    tensor(82.2206)
# 57    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 58  tensor(-177.9646)  tensor(-177.9646)  tensor(-177.9646)
# 59   tensor(103.0653)   tensor(103.0653)   tensor(103.0653)
# 60    tensor(60.8131)    tensor(60.8131)    tensor(60.8131)
# 61   tensor(149.1525)   tensor(149.1525)   tensor(149.1525)
# 62   tensor(133.7067)   tensor(133.7067)   tensor(133.7067)
# 63    tensor(91.5914)    tensor(91.5914)    tensor(91.5914)
# 64   tensor(166.9507)   tensor(166.9507)   tensor(166.9507)
# 65   tensor(133.7067)   tensor(133.7067)   tensor(133.7067)
# 66    tensor(60.8131)    tensor(60.8131)    tensor(60.8131)
#
#                181528             181529             181530  \
# 0     tensor(181528.)    tensor(181529.)    tensor(181530.)
# 1    tensor(-17.7418)   tensor(-17.7418)   tensor(-17.7418)
# 2     tensor(63.2682)    tensor(63.2682)    tensor(63.2682)
# 3     tensor(82.8870)    tensor(82.8870)    tensor(82.8870)
# 4    tensor(167.7155)   tensor(167.7155)   tensor(167.7155)
# 5     tensor(88.4885)    tensor(88.4885)    tensor(88.4885)
# 6    tensor(-67.5295)   tensor(-67.5295)   tensor(-67.5295)
# 7    tensor(-78.5238)   tensor(-78.5238)   tensor(-78.5238)
# 8     tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 9    tensor(149.1525)   tensor(149.1525)   tensor(149.1525)
# 10  tensor(-119.2548)  tensor(-119.2548)  tensor(-119.2548)
# 11    tensor(28.8625)    tensor(28.8625)    tensor(28.8625)
# 12    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 13    tensor(44.3323)    tensor(44.3323)    tensor(44.3323)
# 14   tensor(179.9760)   tensor(179.9760)   tensor(179.9760)
# 15    tensor(88.4885)    tensor(88.4885)    tensor(88.4885)
# 16  tensor(-177.9646)  tensor(-177.9646)  tensor(-177.9646)
# 17   tensor(103.0653)   tensor(103.0653)   tensor(103.0653)
# 18    tensor(74.3538)    tensor(74.3538)    tensor(74.3538)
# 19   tensor(166.9507)   tensor(166.9507)   tensor(166.9507)
# 20   tensor(-54.3524)   tensor(-54.3524)   tensor(-54.3524)
# 21   tensor(157.6986)   tensor(157.6986)   tensor(157.6986)
# 22    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 23    tensor(74.3538)    tensor(74.3538)    tensor(74.3538)
# 24    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 25  tensor(-153.6011)  tensor(-153.6011)  tensor(-153.6011)
# 26  tensor(-103.3455)  tensor(-103.3455)  tensor(-103.3455)
# 27  tensor(-128.9270)  tensor(-128.9270)  tensor(-128.9270)
# 28    tensor(44.3323)    tensor(44.3323)    tensor(44.3323)
# 29   tensor(128.1160)   tensor(128.1160)   tensor(128.1160)
# ..                ...                ...                ...
# 37  tensor(-119.2548)  tensor(-119.2548)  tensor(-119.2548)
# 38   tensor(128.1160)   tensor(128.1160)   tensor(128.1160)
# 39   tensor(-67.7747)   tensor(-67.7747)   tensor(-67.7747)
# 40   tensor(-17.7418)   tensor(-17.7418)   tensor(-17.7418)
# 41   tensor(-68.2657)   tensor(-68.2657)   tensor(-68.2657)
# 42   tensor(158.1229)   tensor(158.1229)   tensor(158.1229)
# 43    tensor(-3.7204)    tensor(-3.7204)    tensor(-3.7204)
# 44   tensor(179.9760)   tensor(179.9760)   tensor(179.9760)
# 45    tensor(78.4832)    tensor(78.4832)    tensor(78.4832)
# 46   tensor(157.6986)   tensor(157.6986)   tensor(157.6986)
# 47   tensor(-26.6565)   tensor(-26.6565)   tensor(-26.6565)
# 48    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 49    tensor(70.7031)    tensor(70.7031)    tensor(70.7031)
# 50  tensor(-128.9270)  tensor(-128.9270)  tensor(-128.9270)
# 51     tensor(3.2087)     tensor(3.2087)     tensor(3.2087)
# 52    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 53    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 54  tensor(-155.5714)  tensor(-155.5714)  tensor(-155.5714)
# 55    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 56    tensor(82.2206)    tensor(82.2206)    tensor(82.2206)
# 57    tensor(94.2335)    tensor(94.2335)    tensor(94.2335)
# 58  tensor(-177.9646)  tensor(-177.9646)  tensor(-177.9646)
# 59   tensor(103.0653)   tensor(103.0653)   tensor(103.0653)
# 60    tensor(60.8131)    tensor(60.8131)    tensor(60.8131)
# 61   tensor(149.1525)   tensor(149.1525)   tensor(149.1525)
# 62   tensor(133.7067)   tensor(133.7067)   tensor(133.7067)
# 63    tensor(91.5914)    tensor(91.5914)    tensor(91.5914)
# 64   tensor(166.9507)   tensor(166.9507)   tensor(166.9507)
# 65   tensor(133.7067)   tensor(133.7067)   tensor(133.7067)
# 66    tensor(60.8131)    tensor(60.8131)    tensor(60.8131)
#
#                181531             181532
# 0     tensor(181531.)    tensor(181532.)
# 1    tensor(-17.7418)   tensor(-17.7418)
# 2     tensor(63.2682)    tensor(63.2682)
# 3     tensor(82.8870)    tensor(82.8870)
# 4    tensor(167.7155)   tensor(167.7155)
# 5     tensor(88.4885)    tensor(88.4885)
# 6    tensor(167.0594)   tensor(167.0594)
# 7    tensor(-78.5238)   tensor(-78.5238)
# 8     tensor(94.2335)    tensor(94.2335)
# 9    tensor(149.1525)   tensor(149.1525)
# 10  tensor(-119.2548)  tensor(-119.2548)
# 11    tensor(28.8625)    tensor(28.8625)
# 12    tensor(94.2335)    tensor(94.2335)
# 13    tensor(44.3323)    tensor(44.3323)
# 14   tensor(179.9760)   tensor(179.9760)
# 15    tensor(88.4885)    tensor(88.4885)
# 16  tensor(-177.9646)  tensor(-177.9646)
# 17   tensor(103.0653)   tensor(103.0653)
# 18    tensor(74.3538)    tensor(74.3538)
# 19   tensor(166.9507)   tensor(166.9507)
# 20   tensor(-54.3524)   tensor(-54.3524)
# 21   tensor(157.6986)   tensor(157.6986)
# 22    tensor(94.2335)    tensor(94.2335)
# 23    tensor(74.3538)    tensor(74.3538)
# 24    tensor(94.2335)    tensor(94.2335)
# 25  tensor(-153.6011)  tensor(-153.6011)
# 26  tensor(-103.3455)  tensor(-103.3455)
# 27  tensor(-128.9270)  tensor(-128.9270)
# 28    tensor(44.3323)    tensor(44.3323)
# 29   tensor(128.1160)   tensor(128.1160)
# ..                ...                ...
# 37  tensor(-119.2548)  tensor(-119.2548)
# 38   tensor(128.1160)   tensor(128.1160)
# 39   tensor(-67.7747)   tensor(-67.7747)
# 40   tensor(-17.7418)   tensor(-17.7418)
# 41   tensor(-68.2657)   tensor(-68.2657)
# 42   tensor(158.1229)   tensor(158.1229)
# 43    tensor(-3.7204)    tensor(-3.7204)
# 44   tensor(179.9760)   tensor(179.9760)
# 45    tensor(78.4832)    tensor(78.4832)
# 46   tensor(157.6986)   tensor(157.6986)
# 47   tensor(-26.6565)   tensor(-26.6565)
# 48    tensor(94.2335)    tensor(94.2335)
# 49    tensor(70.7031)    tensor(70.7031)
# 50  tensor(-128.9270)  tensor(-128.9270)
# 51     tensor(3.2087)     tensor(3.2087)
# 52    tensor(94.2335)    tensor(94.2335)
# 53    tensor(94.2335)    tensor(94.2335)
# 54  tensor(-155.5714)  tensor(-155.5714)
# 55    tensor(94.2335)    tensor(94.2335)
# 56    tensor(82.2206)    tensor(82.2206)
# 57    tensor(94.2335)    tensor(94.2335)
# 58  tensor(-177.9646)  tensor(-177.9646)
# 59   tensor(103.0653)   tensor(103.0653)
# 60   tensor(143.9782)   tensor(143.9782)
# 61   tensor(149.1525)   tensor(149.1525)
# 62   tensor(133.7067)   tensor(133.7067)
# 63    tensor(91.5914)    tensor(91.5914)
# 64   tensor(166.9507)   tensor(166.9507)
# 65   tensor(133.7067)   tensor(133.7067)
# 66   tensor(143.9782)   tensor(143.9782)
#
# [67 rows x 181533 columns]

# %%
train_x	= torch.FloatTensor(df_train.values[:,:-3].astype('float64'))
print df_train.values[1,:]
print train_x[1,:]

print df_train.shape
# Out:
# [1.20000000e-01 1.22222222e-01 1.22222222e-01 ... 6.32681618e+01
#  6.32681618e+01 1.41866776e+02]
# tensor([ 0.1200,  0.1222,  0.1222,  ..., 63.2682, 63.2682, 63.2682])
# (66, 181536)

# %%
# Use raw features
train_x	= torch.FloatTensor(df_train.values[:,:-3].astype('float64'))
test_x = torch.FloatTensor(df_eval.values[:,:-3].astype('float64'))

train_y = torch.FloatTensor(df_train.values[:,-3].astype('float64'))
test_y = torch.FloatTensor(df_eval.values[:,-3].astype('float64'))
dtype = torch.float
#device = torch.device("cpu") # Uncomment this to run on CPU
if len(sys.argv) > 1:
    gpu_id=sys.argv[1]
    device = torch.device("cuda:"+gpu_id)
else:
    device = torch.device("cuda:0")
print(device)

epochs = 10000
N = 16 #batch size
D_in = train_x.shape[1]
D_out = 1
drop = 0.4
#FFN Model
